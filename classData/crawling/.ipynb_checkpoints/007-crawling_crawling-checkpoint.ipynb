# %% [markdown]
# ## Crawling & Crawing

# %% [markdown]
# ### 1. 실전 예제: 크롤링
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격 추출하기

# %%
# 여기는 내가 작성

# %%
import requests
from bs4 import BeautifulSoup

URL = "http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06"

res = requests.get(URL)
if res.status_code == 200:
    soup = BeautifulSoup(res.text, 'html.parser')
    cards = soup.select('.best-list')[1].select('ul > li')

    for index, card in enumerate(cards):
        title = card.select_one('.itemname')
        price = card.select_one('.s-price > strong')
        print(index + 1, title.get_text(), price.get_text())
# Out:
# 1 [블루스카이]인증점 삼성 공기청정기 AX60N5580WDD 전국무료배송 286,000원
# 2 [삼성전자](사전예약판매) 갤럭시S21 5G 자급제폰 SM-G991N 999,900원
# 3 [삼성전자](사전예약판매) 갤럭시S21 5G 자급제폰 SM-G991N 999,900원
# 4 [삼성전자](사전판매) 갤럭시S21 울트라 5G 자급제폰 SM-G998N 1,452,000원
# 5 [다이슨]본사  다이슨 에어랩 스타일러 컴플리트 545,090원
# 6 [삼성전자](사전판매) 갤럭시S21 울트라 5G 자급제폰 SM-G998N 1,452,000원
# 7 부토 전기찜기 계란찜기 간편세척 NBE622W 다용도찜기 22,900원
# 8 [샤오미]샤오미 미밴드5 여우미 공식수입 정식 한글판(미개봉) 38,900원
# 9 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 바이올렛 239,800원
# 10 윤남텍 간편세척 초음파 다목적 가습기/YN-101/G마켓 69,000원
# 11 [애플]Apple 정품 에어팟 프로 MWP22KH/A 257,530원
# 12 [삼성전자]혜택가68.7만  삼성 제트 VS20R9078S3CS 청정스테이션 767,000원
# 13 [삼성전자](사전판매) 갤럭시S21 플러스 5G 자급제폰 SM-G996N 1,199,000원
# 14 SKT 기변/번이 아이폰12 MINI_128G 완납/선약 718,520원
# 15 [닌텐도]닌텐도 모여봐요 동물의 숲(SWITCH) 5천원 E캐시 증정 61,060원
# 16 SKT 기변/번이 아이폰 12 PRO 256G 완납/선택약정 1,164,460원
# 17 무선 블루투스 5.0 이어폰 3개 1+1+1 LED 27,400원
# 18 [에이엠]am 멀티 다지기 FC-J18 (용기 3개  보관커버 포함) + 49,900원
# 19 [삼성전자]혜택56만원대)제트2.0 VS15R8577S5CW 청정스테이션 649,000원
# 20 [단미]2구 샌드위치 크로플 와플 메이커 화이트(DA-SAN02) 64,900원
# 21 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 블랙 239,800원
# 22 [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K 20,800원
# 23 [삼성전자]혜택가8.2만! 삼성 세라믹 전자레인지 MS23K3523AK 89,900원
# 24 [LG전자][LG전자][공식판매점]LG 전자레인지 MW22CD9 (22L) 121,810원
# 25 [닌샵]스마트 앵글 스탠드 거치대 휴대폰 거치대 생활용품 7,430원
# 26 [삼성전자]인증점 삼성 비스포크 전자레인지 MS23T5018AW 23L 143,120원
# 27 [쿠쿠](본사직영) CRP-DHP0610FD 쿠쿠 6인용 IH전기압력밥솥 243,640원
# 28 [샤오미]샤오미 Mi TV 스틱 글로벌버전 1080P(Full HD) 블랙 39,200원
# 29 [필립스]PHILIPS 전기면도기 SkinIQ 5000 S5581/10 버건디레드 129,000원
# 30 [삼성전자]21리터 세라믹전자렌지 RE-C21KB 인증점 70,400원
# 31 [LG TV] [E][65] LG 올레드 울트라 HD TV 163CM (OLED65BXFN 2,850,000원
# 32 SKT 기변/번이 아이폰 12 Mini 64G 완납/선택약정 662,200원
# 33 로지텍 G304 무선 게이밍 마우스 병행 밀봉박스새상품 36,740원
# 34 [로지텍] 로지텍  K380 블루투스 한글자판 정품 키보드 4종 34,900원
# 35 [갤럭시]핸드폰케이스 S20 S10 노트20 노트10 노트9 노트8 9,900원
# 36 SKT 기변/번이 아이폰 12 Mini 128G 완납/선택약정 738,760원
# 37 [삼성전자]비스포크 냉장고 RF85T91S1AP 색상선택(+중복할인) 1,689,000원
# 38 [필립스]1200 에스프레소 머신 EP1200/03 409,000원
# 39 [통돌이]LG전자 블랙라벨플러스 세탁기 T18MT DD모터 18kg 639,000원
# 40 [삼성전자]더플레이트 NZ31T3703PWB 인덕션 용기 패키지 인증점 207,910원
# 41 [로지텍]로지텍코리아 C270 HD 웹캠 온라인수업 노이즈감소 31,000원
# 42 [삼성전자](사전판매) 갤럭시S21 플러스 5G 자급제폰 SM-G996N 1,199,000원
# 43 [삼성전자]인증점 삼성 진공 청소기 VC33M2110LP  (7%중복쿠폰) 83,900원
# 44 SKT 기변/번이 아이폰 12 128G 완납/선택약정 900,900원
# 45 [쿠쿠](현대Hmall)본사직영) CRP-CHP1010FD 쿠쿠 10인용 IH전기압력밥솥 313,180원
# 46 [로지텍]로지텍 M350 페블 무소음 무선 블루투스 마우스 병행 19,360원
# 47 [바비리스]D990K- 파워 스피드 2000W 전문가용 드라이기 20,800원
# 48 [워블]워블 세탁기 14kg WA14T6262BY 전자동 듀얼DD모터 395,000원
# 49 [통돌이]LG 통돌이 TR12BL 일반세탁기 12kg 스마트 인버터모터 345,000원
# 50 [에버홈]글라스텐 다지기 EV-MC6000 마늘 고기 야채 멀티다지기 58,900원
# 51 [크리스탈실버]NB정품 F100A-블랙 모니터암 거치대 35인치/12kg 거치 31,690원
# 52 [엘지전자]   LG 코드제로 A9S 무선청소기 A9370 IK/SK/VK 746,070원
# 53 [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식 21,900원
# 54 [illi]일리 프란시스 커피머신 Y3.3 화이트 + 시음캡슐 14개 115,230원
# 55 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 실버 239,800원
# 56 [삼성전자]인증점 삼성 UHD TV 125cm(50) KU50UT8070FXKR 스탠드 639,000원
# 57 [삼성전자]비스포크 양문형냉장고 RF85T911101 혜택가 158만원대 1,639,000원
# 58 [샤오미]미 TV 스틱/1080P/한국어 지원/ 글로벌버전/블랙 38,900원
# 59 [닌텐도]스위치 슈퍼 마리오 파티 60,200원
# 60 [아이디어패드]SLIM5-15ITL Premiere i5 FreeDos MX450탑재11세대인텔 849,000원
# 61 [한성컴퓨터]TFX5450UC/울트라북/르누아르/라이젠 4500U 699,000원
# 95 [다이슨]다이슨 본사 에어랩 스타일러 볼륨앤쉐이프 490,490원
# 96 곰표한일 워셔블 전기요 모음전 전기장판/매트/캠핑 17,510원
# 97 [구글]구글 크롬캐스트3 폰 무선TV연결 넷플릭스 유튜브 54,900원
# 98 [삼성전자]삼성 그랑데 WF19T6000KP 1등급 무료배송 802,000원
# 99 [닌텐도]스위치 게임 슈퍼 마리오 3D 월드+퓨리 월드+사은품 59,800원
# 100 [삼성전자]전자동 세탁기 듀얼 DD모터 WA18R7550KV 18Kg 579,000원

# %%
# 여기는 모범 답안

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    print (title.get_text(), price.get_text(), title['href'])

# %% [markdown]
# ### 2. 실전 예제: 크롤링 & 크롤링
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격, 그리고 판매업체 추출하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    res_info = requests.get(title['href'])
    soup_info = BeautifulSoup(res_info.content, 'html.parser')
    provider_info = soup_info.select_one('div.item-topinfo > div.item-topinfo_headline > p > a > strong')
    print (title.get_text(), price.get_text(), title['href'], provider_info.get_text())

# %% [markdown]
# ### 3. 실전 예제: 크롤링 & 크롤링 + 엑셀
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격, 그리고 판매업체 추출하기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.append(['랭킹', '상품명', '판매가격', '상품상세링크', '판매업체'])
excel_sheet.column_dimensions['B'].width = 80
excel_sheet.column_dimensions['C'].width = 20
excel_sheet.column_dimensions['D'].width = 80
excel_sheet.column_dimensions['E'].width = 20

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')

bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    
    res_info = requests.get(title['href'])
    soup_info = BeautifulSoup(res_info.content, 'html.parser')
    provider_info = soup_info.select_one('div.item-topinfo > div.item-topinfo_headline > p > a > strong')
    print(index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text())
    excel_sheet.append([index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text()])
    excel_sheet.cell(row=index+2 , column=4).hyperlink = title['href']


cell_A1 = excel_sheet['A1'] # 셀 선택하기
cell_A1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_A1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_B1 = excel_sheet['B1'] # 셀 선택하기
cell_B1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_B1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_C1 = excel_sheet['C1'] # 셀 선택하기
cell_C1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_C1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_D1 = excel_sheet['D1'] # 셀 선택하기
cell_D1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_D1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_E1 = excel_sheet['E1'] # 셀 선택하기
cell_E1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_E1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

excel_file.save('BESTPRODUCT_COM_GMARKET.xlsx')
excel_file.close()
