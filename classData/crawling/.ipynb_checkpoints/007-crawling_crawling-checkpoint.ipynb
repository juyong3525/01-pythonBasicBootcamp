# %% [markdown]
# ## Crawling & Crawing

# %% [markdown]
# ### 1. 실전 예제: 크롤링
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격 추출하기

# %%
# 여기는 내가 작성

# %%
import requests
import openpyxl
from bs4 import BeautifulSoup

# 엑셀 파일에 쓰기 ( 랭킹, 상품명, 판매가격, 제품 상세 링크, 판매 업체 )
excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.append(['랭킹', '상품명', '판매가격', '제품 상세 링크', '판매 업체'])
excel_sheet.column_dimensions['B'].width = 80
excel_sheet.column_dimensions['C'].width = 20
excel_sheet.column_dimensions['D'].width = 80
excel_sheet.column_dimensions['E'].width = 20


# 크롤링
URL = "http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06"

res = requests.get(URL)
if res.status_code == 200:
    soup = BeautifulSoup(res.content, 'html.parser')
    cards = soup.select('.best-list')[1].select('ul > li')

    for index, card in enumerate(cards):
        title = card.select_one('.itemname')    # 상품명
        price = card.select_one('.s-price > strong')    # 판매 가격
        link = title['href']    # 제품 상세 링크

        res_info = requests.get(link)
        if res_info.status_code == 200:
            print(f'Running: {index + 1}')
            soup_info = BeautifulSoup(res_info.content, 'html.parser')
            provider_info = soup_info.select_one('.text__seller > a')   # 판매 업체

            excel_row = [index + 1, title.get_text(), price.get_text(),
                         link, provider_info.get_text()]
            excel_sheet.append(excel_row)
            # 엑셀 파일 D열에 링크를 하이퍼링크로 만든다
            excel_sheet.cell(row=index+2, column=4).hyperlink = link


cells = ['A1', 'B1', 'C1', 'D1', 'E1']
for cell_name in cells:
    cell = excel_sheet[cell_name]
    cell.alignment = openpyxl.styles.Alignment(horizontal='center')    # 가운데 정렬
    cell.font = openpyxl.styles.Font(color="01579B")    # 폰트 색깔 변경

excel_file.save("gmarket_best.xlsx")
excel_file.close()
print('Done!')
# Out:
# 1 [삼성전자](사전예약판매) 갤럭시S21 5G 자급제폰 SM-G991N 999,900원 삼성공식온라인판매점
# 2 [삼성전자](사전예약판매) 갤럭시S21 5G 자급제폰 SM-G991N 999,900원 삼성공식온라인판매점
# 3 [블루스카이]인증점 삼성 공기청정기 AX60N5580WDD 전국무료배송 286,000원 삼성공식다원
# 4 [삼성전자](사전판매) 갤럭시S21 울트라 5G 자급제폰 SM-G998N 1,452,000원 삼성공식온라인판매점
# 5 [다이슨]본사  다이슨 에어랩 스타일러 컴플리트 545,090원 다이슨코리아유한회사
# 6 [삼성전자](사전판매) 갤럭시S21 울트라 5G 자급제폰 SM-G998N 1,452,000원 삼성공식온라인판매점
# 7 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 바이올렛 239,800원 jeyoumall
# 8 [샤오미]샤오미 미밴드5 여우미 공식수입 정식 한글판(미개봉) 38,900원 스마일배송
# 9 [삼성전자](사전판매) 갤럭시S21 플러스 5G 자급제폰 SM-G996N 1,199,000원 삼성공식온라인판매점
# 10 [애플]Apple 정품 에어팟 프로 MWP22KH/A 257,530원 Apple공식판매점
# 11 SKT 기변/번이 아이폰12 MINI_128G 완납/선약 708,400원 피에스앤마케팅
# 12 SKT 기변/번이 아이폰 12 PRO 256G 완납/선택약정 1,164,460원 CJ오쇼핑
# 13 윤남텍 간편세척 초음파 다목적 가습기/YN-101/G마켓 69,000원 윤남텍
# 14 [닌텐도]닌텐도 모여봐요 동물의 숲(SWITCH) 5천원 E캐시 증정 61,060원 지피클럽
# 15 [에이엠]am 멀티 다지기 FC-J18 (용기 3개  보관커버 포함) + 49,900원 GS홈쇼핑
# 16 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 블랙 239,800원 jeyoumall
# 17 무선 블루투스 5.0 이어폰 3개 1+1+1 LED 27,400원 cylin678
# 18 [삼성전자]혜택56만원대)제트2.0 VS15R8577S5CW 청정스테이션 649,000원 삼성공식판매보보
# 19 [닌샵]스마트 앵글 스탠드 거치대 휴대폰 거치대 생활용품 7,430원 스마일배송
# 20 [삼성전자]혜택가68.7만  삼성 제트 VS20R9078S3CS 청정스테이션 767,000원 삼성공식다원
# 21 [단미]2구 샌드위치 크로플 와플 메이커 화이트(DA-SAN02) 64,900원 스마일배송
# 22 [LG전자][LG전자][공식판매점]LG 전자레인지 MW22CD9 (22L) 121,810원 신세계백화점
# 23 [삼성전자]혜택가8.2만! 삼성 세라믹 전자레인지 MS23K3523AK 89,900원 삼성공식판매다솜
# 24 [LG TV] [E][65] LG 올레드 울트라 HD TV 163CM (OLED65BXFN 2,850,000원 롯데 홈쇼핑
# 25 [갤럭시]핸드폰케이스 S20 S10 노트20 노트10 노트9 노트8 9,900원 제로큐브
# 26 [쿠쿠](현대Hmall)본사직영) CRP-CHP1010FD 쿠쿠 10인용 IH전기압력밥솥 313,180원 현대Hmall
# 27 [비달사순]비달사순 2000W 전문가용 헤어드라이기 VSD5129K 20,800원 스마일배송
# 28 [삼성전자](사전판매) 갤럭시S21 플러스 5G 자급제폰 SM-G996N 1,199,000원 삼성공식온라인판매점
# 29 SKT 기변/번이 아이폰 12 Mini 128G 완납/선택약정 738,760원 CJ오쇼핑
# 30 [엘지전자]   LG 코드제로 A9S 무선청소기 A9370 IK/SK/VK 746,070원 롯데 홈쇼핑
# 31 [로지텍]로지텍코리아 C270 HD 웹캠 온라인수업 노이즈감소 31,000원 기가바이트공식스토어
# 32 [샤오미]샤오미 Mi TV 스틱 글로벌버전 1080P(Full HD) 블랙 39,200원 EZBUY_TRADE
# 33 [삼성전자]인증점 삼성 비스포크 전자레인지 MS23T5018AW 23L 143,120원 (주)평강프라자
# 34 로지텍 G304 무선 게이밍 마우스 병행 밀봉박스새상품 36,740원 pcgamemall
# 35 [삼성전자]21리터 세라믹전자렌지 RE-C21KB 인증점 70,400원 삼성공식파트너KDL
# 36 [바비리스]D990K- 파워 스피드 2000W 전문가용 드라이기 20,800원 스마일배송
# 37 [로지텍] 로지텍  K380 블루투스 한글자판 정품 키보드 4종 34,900원 (주)펜스터
# 38 [통돌이]LG전자 블랙라벨플러스 세탁기 T18MT DD모터 18kg 639,000원 LG공식총판
# 39 [삼성전자]더플레이트 NZ31T3703PWB 인덕션 용기 패키지 인증점 207,910원 삼성공식파트너KDL
# 40 부토 전기찜기 계란찜기 간편세척 NBE622W 다용도찜기 22,900원 스마일배송
# 41 [에버홈]글라스텐 다지기 EV-MC6000 마늘 고기 야채 멀티다지기 58,900원 스마일배송
# 42 [삼성전자]갤럭시버즈 프로 블루투스이어폰 ANC SM-R190 실버 239,800원 jeyoumall
# 43 [필립스]PHILIPS 전기면도기 SkinIQ 5000 S5581/10 버건디레드 129,000원 (주)필립스코리아
# 44 [필립스]1200 에스프레소 머신 EP1200/03 409,000원 스마일배송
# 45 [로지텍]로지텍 M350 페블 무소음 무선 블루투스 마우스 병행 19,360원 pcgamemall
# 46 [삼성전자]인증점 삼성 진공 청소기 VC33M2110LP  (7%중복쿠폰) 83,900원 (주)평강프라자
# 47 [통돌이]LG 통돌이 TR12BL 일반세탁기 12kg 스마트 인버터모터 345,000원 LG공식총판
# 48 [쿠쿠](본사직영) CRP-DHP0610FD 쿠쿠 6인용 IH전기압력밥솥 243,640원 신세계몰
# 49 [워블]워블 세탁기 14kg WA14T6262BY 전자동 듀얼DD모터 395,000원 삼성공식판매회산
# 50 [한성컴퓨터]TFX5450UC/울트라북/르누아르/라이젠 4500U 699,000원 (주)한성컴퓨터
# 51 [삼성전자]비스포크 냉장고 RF85T91S1AP 색상선택(+중복할인) 1,689,000원 (주)평강프라자
# 52 SKT 기변/번이 아이폰 12 Mini 64G 완납/선택약정 662,200원 CJ오쇼핑
# 53 [닌텐도]슈퍼마리오 3D월드 + 퓨리월드 특전포함 2/15 순차출고 59,800원 지피클럽
# 54 [illi]일리 프란시스 커피머신 Y3.3 화이트 + 시음캡슐 14개 115,230원 vitatrausa
# 55 [크리스탈실버]NB정품 F100A-블랙 모니터암 거치대 35인치/12kg 거치 31,690원 지아이엘
# 56 닌텐도 스위치 동물의 숲 에디션 배터리 개선판 443,900원 아이게임몰1
# 57 [샤오미]미 TV 스틱/1080P/한국어 지원/ 글로벌버전/블랙 38,900원 샤오미공식파트너
# 58 [삼성전자]공식파트너 삼성 비스포크 전자레인지 MG23T5018CG 159,000원 삼성공식판매다솜
# 59 [애플]애플 펜슬 2세대 MU8F2KH/A 158,340원 Apple공식판매점
# 60 [유닉스]메탈티 무광블랙 1600W 헤어 드라이기 UN-A1610 접이식 23,900원 스마일배송
# 61 [닌텐도]스위치 슈퍼 마리오 파티 59,590원 지피클럽
# 62 안방그릴+보관가방 179,000원 K쇼핑
# 63 [삼성전자]양문형냉장고 푸드쇼케이스 3도어 RS84T5041WW 인증점M 919,000원 (주)문성전자
# 64 [LG TV] [E][1등급][75] LG 울트라 HD TV 189CM (75UN7850K 2,190,000원 롯데 홈쇼핑
# 65 [스피디]에어 그랩 차량용 고속 무선 충전 거치대 10,900원 비앤디닷컴
# 66 [삼성전자]인증점 삼성 CUHD TV 4K KU43UT8070FXKR 스탠드 579,000원 삼성공식판매보보
# 67 르 꽁뜨 by 헤어 속볼륨 펌브러쉬 59,900원 GS홈쇼핑
# 68 [샤오미]샤오미 DUKA ES1 정밀 전자저울--8KG / 무료배송 10,900원 meetg9
# 69 [샤오미]Xiaomi Dreame 최신 청소기 V10  한국형 어댑터설명서 179,000원 Liangzhi12
# 70 [삼성전자]갤럭시버즈 프로 ANC 블루투스 이어폰 SM-R190 블랙 239,800원 삼성랜드
# 71 [삼성전자]인증점 삼성 UHD TV 125cm(50) KU50UT8070FXKR 스탠드 639,000원 삼성공식판매다솜
# 72 [갤럭시]C타입 고속충전케이블 노트20/S20/S10/노트10 1+1+1 4,900원 제로큐브
# 73 [쿠진아트]양면 그릴5 전골팬 GR-5KR + 와플플레이트 최저 129600 162,000원 스마일배송
# 74 삼성전자 DDR4 8G PC4-21300 (정품)-S 41,420원 스타컴1
# 75 [애플]애플 에어팟 2세대 유선충전 MV7N2KH/A 155,610원 Apple공식판매점
# 76 [삼성전자]비스포크 양문형냉장고 RF85T911101 혜택가 158만원대 1,639,000원 (주)문성전자
# 77 [레드울프]노트20 S20 5G/노트10 9/S10/S9 울트라 가죽 폰케이스 19,900원 레드울프
# 78 [쿠쿠](본사직영) CRP-DHP0610FD 쿠쿠 6인용 IH전기압력밥솥 240,530원 신세계몰
# 79 [로지텍]로지텍코리아 K380 블루투스 키보드 퓨어화이트 /456 34,860원 나노YS
# 80 [워블]전자동 워블세탁기13kg WA13T5262BW 화이트 듀얼DD모터 376,000원 삼성공식판매회산
# 81 AMD 라이젠5-4세대 5600X (버미어) (멀티팩)-S 431,200원 스타컴1
# 82 [필립스]PHILIPS 전기면도기 SkinIQ 7000 S7788/54 다크 크롬 209,000원 (주)필립스코리아
# 83 [통돌이]LG 통돌이 TR14WK1 일반세탁기 14kg 인버터모터 385,000원 LG공식총판
# 84 [에이수스]ASUS 노트북 D513IA-BQ380 라이젠 R5/8GB/NVME 256G 599,000원 ASUS대리점
# 85 [갤럭시]갤럭시탭 S6 10.4 Lite WiFi 64G 그레이 RNR 509,830원 주식회사리플레이
# 86 [삼성전자]인증점 삼성 UHD TV 163cm(65) KU65UT8070FXKR 스탠드 1,219,000원 삼성공식판매다솜
# 87 [닌텐도]스위치 게임 슈퍼 마리오 3D 월드+퓨리 월드+사은품 59,800원 해피플러스주식회사
# 88 [삼성전자]비스포크 2도어 슬림 냉장고 RB33T3004AP 혜택가62만 647,000원 삼성공식파트너KDL
# 89 [구글]구글 크롬캐스트3 폰 무선TV연결 넷플릭스 유튜브 54,900원 스마일배송
# 90 [삼성전자]인증점 삼성 그랑데 WF19T6000KP+DV14T8520BP 무료배송 1,679,000원 삼성하나로
# 91 [대우]대우 에어프라이어 2.6L(블랙) DEF-D2600 49,900원 스마일배송
# 92 [일렉트로룩스]에르고라피도 18V 무선청소기 ZB3311AK +4종노즐확장팩 149,000원 스마일배송
# 93 [쿠첸]쿠첸 6인용 전기압력밥솥/전기밥솥/밥솥CJS-FA06010KV 104,600원 쿠첸종합몰
# 94 [삼성전자]인증점 삼성 전자레인지 MS23K3513AW 23L (7%중복쿠폰) 87,900원 (주)평강프라자
# 95 [샤오미]샤오미 공기청정기 미에어 3C 한글판 /2020최신 99,000원 샤오미공식파트너
# 96 [로지텍]로지텍 Pebble 무선 블루투스 마우스 M350 /병행/ 20,400원 올가람
# 97 [샤오미]드리미 로봇 청소기 F9/한국어 미홈 앱 연결 가능 182,000원 Liangzhi12
# 98 [다이슨]다이슨 본사 에어랩 스타일러 볼륨앤쉐이프 490,490원 다이슨코리아유한회사
# 99 [삼성전자]삼성 그랑데 WF19T6000KP 1등급 무료배송 802,000원 삼성하나로
# 100 로지텍 G102 2세대 LIGHTSYNC RGB PC방 팩 (블랙) 19,490원 아이텐츠샵

# %%
# 여기는 모범 답안

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    print (title.get_text(), price.get_text(), title['href'])

# %% [markdown]
# ### 2. 실전 예제: 크롤링 & 크롤링
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격, 그리고 판매업체 추출하기

# %%
import requests
from bs4 import BeautifulSoup

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')
bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    res_info = requests.get(title['href'])
    soup_info = BeautifulSoup(res_info.content, 'html.parser')
    provider_info = soup_info.select_one('div.item-topinfo > div.item-topinfo_headline > p > a > strong')
    print (title.get_text(), price.get_text(), title['href'], provider_info.get_text())

# %% [markdown]
# ### 3. 실전 예제: 크롤링 & 크롤링 + 엑셀
# * 이커머스(지마켓) 베스트100 상품 타이틀/가격, 그리고 판매업체 추출하기

# %%
import requests, openpyxl
from bs4 import BeautifulSoup

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.append(['랭킹', '상품명', '판매가격', '상품상세링크', '판매업체'])
excel_sheet.column_dimensions['B'].width = 80
excel_sheet.column_dimensions['C'].width = 20
excel_sheet.column_dimensions['D'].width = 80
excel_sheet.column_dimensions['E'].width = 20

res = requests.get('http://corners.gmarket.co.kr/Bestsellers?viewType=G&groupCode=G06')
soup = BeautifulSoup(res.content, 'html.parser')

bestlists = soup.select('div.best-list')
bestitems = bestlists[1]
products = bestitems.select('ul > li')

for index, product in enumerate(products):
    title = product.select_one('a.itemname')
    price = product.select_one('div.s-price > strong')
    
    res_info = requests.get(title['href'])
    soup_info = BeautifulSoup(res_info.content, 'html.parser')
    provider_info = soup_info.select_one('div.item-topinfo > div.item-topinfo_headline > p > a > strong')
    print(index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text())
    excel_sheet.append([index + 1, title.get_text(), price.get_text(), title['href'], provider_info.get_text()])
    excel_sheet.cell(row=index+2 , column=4).hyperlink = title['href']


cell_A1 = excel_sheet['A1'] # 셀 선택하기
cell_A1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_A1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_B1 = excel_sheet['B1'] # 셀 선택하기
cell_B1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_B1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_C1 = excel_sheet['C1'] # 셀 선택하기
cell_C1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_C1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_D1 = excel_sheet['D1'] # 셀 선택하기
cell_D1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_D1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

cell_E1 = excel_sheet['E1'] # 셀 선택하기
cell_E1.alignment = openpyxl.styles.Alignment(horizontal='center') # 중앙정렬하기
cell_E1.font = openpyxl.styles.Font(color="01579B") # 폰트 색깔 바꾸기
# 색상값 찾기: https://material.io/design/color/#tools-for-picking-colors

excel_file.save('BESTPRODUCT_COM_GMARKET.xlsx')
excel_file.close()
